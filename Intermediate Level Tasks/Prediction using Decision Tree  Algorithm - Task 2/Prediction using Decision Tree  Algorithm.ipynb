# %% [markdown]
# # LetsGrowMore (LGMVIP) - "DATA SCIENCE INTERN"
#
# ## LGMVIP March-23
#
# ### AUTHOR - Mutyala Harini
#
# #### Intermediate Level Task
#
# #### TASK-6- Prediction using Decision Tree Algorithm :
#
# Creating the Decision Tree classifier and visualize it graphically. The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# ### Dataset link : https://bit.ly/3kXTdox

# %% [markdown]
# ### Importing Libraries

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score, plot_confusion_matrix, classification_report,confusion_matrix

# %% [markdown]
# ### Loading the dataset

# %%
# Loading the Dataset
# Reading the Dataset
df=pd.read_csv("Iris.csv")
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# Our Decision Tree model requires the data in numerical form so we need to convert the flower names to numbers
#
# iris-setosa = 0, iris-versicolor = 1, iris-virginica = 2

# %% [markdown]
# Now, we will create list of feature columns of sepal and petal lengths and widths

# %%
features = list(df.columns[1:5])
features
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %% [markdown]
# Creating X and y data for training. X will contain or features and y will contain the flower types

# %%
y = df['Species']
x = df[features]

# %% [markdown]
# Now we will construct the decision tree with the help of decision tree classifier from sklearn

# %%
classifier = tree.DecisionTreeClassifier()
classifier = classifier.fit(x,y)

# %% [markdown]
# We will display our Decision tree with the help of sklearn

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,16))
tree.plot_tree(classifier, feature_names= features, class_names=class_names, filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'PetalLengthCm <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = Iris-setosa'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = Iris-setosa'),
#  Text(0.5769230769230769, 0.75, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = Iris-versicolor'),
#  Text(0.3076923076923077, 0.5833333333333334, 'PetalLengthCm <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = Iris-versicolor'),
#  Text(0.15384615384615385, 0.4166666666666667, 'PetalWidthCm <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]\nclass = Iris-versicolor'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = Iris-versicolor'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
# ...

# %% [markdown]
# We have successfully build decision tree and visualized it very easily.
#
# We will now give any random features to the classifier and see which class it belongs to

# %%
test_features = [7,6,3,2]
classifier.predict([test_features])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)

# %% [markdown]
# Here, we can see that above features belong to class 1 i.e. Iris-versicolor flower

# %% [markdown]
# ### Thank You!
#
# ### -By Mutyala Harini
